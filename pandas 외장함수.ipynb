# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1,3,5,np.nan, 6, 8])
print(s)

# %%
dates = pd.date_range('20221022', periods = 6)
dates

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=['A', 'B', 'C', 'D'])
df

# %%
df.head()

# %%
df.index

# %%
df.columns

# %%
df.values

# %%
df.info()

# %%
df.describe()
#mean 평균 std 표준편차

# %%
df.sort_values(by='B', ascending =False)
